# %% [markdown]
# ## Optical Flow
#
# * Sparse: Lucas-Kanade
# * Dense: Gunnar Farneback

# %%
# enable showing matplotlib image inline
# %matplotlib inline
# %matplotlib nbagg

import numpy as np 
import cv2
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %% [markdown]
# ### Spare Optical Flow

# %%
VIDEO_PATH = 'domo_running.mp4'

# params for ShiTomasi corner detection
FEATURE_COUNT = 100
FEATURE_PARAMS = dict(
    maxCorners=FEATURE_COUNT,
    qualityLevel=0.3,
    minDistance=7,
    blockSize=7
)

# Parameters for lucas kanade optical flow
LK_PARAMS = dict(
    winSize  = (15,15),
    maxLevel = 2,
    criteria = (cv2.TERM_CRITERIA_COUNT | cv2.TERM_CRITERIA_EPS, 10, 0.03)
)

# color for drawing (create FEATURE_COUNT colors each of these is RGB color)
COLOR = np.random.randint(0, 255,(FEATURE_COUNT, 3))

def frames():
    """
    Get frames from video
    """

    video = cv2.VideoCapture(VIDEO_PATH)
    success = True

    while(success):
        success, current = video.read()
        if not success:
            break
        yield current
    else:
        video.release()

def optical_flow_spare():
    '''
        Detect and Draw Optical Flow 
    '''
    get_features = lambda f: cv2.goodFeaturesToTrack(f, mask=None, **FEATURE_PARAMS)
    to_grayscale = lambda f: cv2.cvtColor(f, cv2.COLOR_BGR2GRAY)
    
    previous_is_set = False
    p_frame = None
    p_features = []
    mask = []
    
    
    for frame in frames():
        glayed = to_grayscale(frame)
        
        if not previous_is_set:
            p_frame = glayed
            p_features = get_features(p_frame)
            mask = np.zeros_like(frame)
            
            if p_features is not None:
                previous_is_set = True
            else:
                continue
        else:
            # calculate optical flow
            c_features, st, err = cv2.calcOpticalFlowPyrLK(p_frame, glayed, p_features, None, **LK_PARAMS)
            
            if c_features is None:
                continue
            else:
                # select good points (st = 1 if tracking is successed)
                tracked = c_features[st==1]
                tracked_in_previous = p_features[st==1]
                
                # draw line
                for i,(current, previous) in enumerate(zip(tracked, tracked_in_previous)):
                    x1, y1 = current.ravel()
                    x0, y0 = previous.ravel()
                    mask = cv2.line(mask, (x1, y1), (x0, y0), COLOR[i].tolist(), 2)
                    frame = cv2.circle(frame, (x1, y1), 5, COLOR[i].tolist(), -1)
                
                img = cv2.add(frame, mask)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # OpenCV has color BGR
                yield img
                
                p_frame = glayed.copy()
                p_features = c_features.reshape(-1, 1, 2)
def draw(flow_func):
    fig = plt.figure()
    ims = []

    for f in flow_func():
        ims.append([plt.imshow(f)])

    ani = animation.ArtistAnimation(fig, ims)
    plt.axis("off")
    plt.show()

draw(optical_flow_spare)

# %% [markdown]
# ### Dense Optical Flow

# %%
def optical_flow_dense():
    """
    Detect and Draw Optical Flow by Dense
    """
    to_grayscale = lambda f: cv2.cvtColor(f, cv2.COLOR_BGR2GRAY)
    
    
    previous_is_set = False
    p_frame = None
    hsv = []
    
    params = dict(
        pyr_scale=0.5,
        levels=3,
        winsize=15,
        iterations=3,
        poly_n=5,
        poly_sigma=1.1,
        flags=0
    )
    
    for frame in frames():
        glayed = to_grayscale(frame)
        
        if not previous_is_set:
            p_frame = glayed
            hsv = np.zeros_like(frame)
            hsv[...,1] = 255
            previous_is_set = True
        else:
            # calculate optical flow
            flow = cv2.calcOpticalFlowFarneback(p_frame, glayed, None, **params)
            
            if flow is None:
                continue
            else:
                # optical flow's magnitudes and angles
                mag, ang = cv2.cartToPolar(flow[...,0], flow[...,1])
                hsv[...,0] = ang*180/np.pi/2
                hsv[...,2] = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX)  # magnitude to 0-255 scale
                img = cv2.cvtColor(hsv,cv2.COLOR_HSV2RGB)
                
                yield img
                
                p_frame = glayed.copy()
draw(optical_flow_dense)

# %%
# !nautilus .
# Out:
# VLC media player 3.0.8 Vetinari (revision 3.0.8-0-gf350b6b5a7)
# [000056275f94ed60] dbus interface error: Failed to connect to the D-Bus session daemon: Did not receive a reply. Possible causes include: the remote application did not send a reply, the message bus security policy blocked the reply, the reply timeout expired, or the network connection was broken.
# [000056275f94ed60] main interface error: no suitable interface module
# [000056275f8775f0] main libvlc error: interface "dbus,none" initialization failed
# [000056275f8775f0] main libvlc error: D-Bus session bus connection failure: Did not receive a reply. Possible causes include: the remote application did not send a reply, the message bus security policy blocked the reply, the reply timeout expired, or the network connection was broken.
# [000056275f8775f0] main libvlc: Running vlc with the default interface. Use 'cvlc' to use vlc without interface.
# Qt: Session management error: Could not open network socket
# [00007fade0170600] dbus_screensaver inhibit error: cannot connect to session bus: Did not receive a reply. Possible causes include: the remote application did not send a reply, the message bus security policy blocked the reply, the reply timeout expired, or the network connection was broken.
# [00007fadd4021590] transform filter error: Unsupported pixel size 0 (chroma VAOP)
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd4020840] main filter error: Failed to create video converter
# [00007fadd47be490] chain filter error: Too high level of recursion (3)
# [00007fadd40203e0] main filter error: Failed to create video converter
# [00007fadd47be490] chain filter error: Too high level of recursion (3)
# [00007fadd40203e0] main filter error: Failed to create video converter
# [00007fadd47be490] chain filter error: Too high level of recursion (3)
# [00007fadd40203e0] main filter error: Failed to create video converter
# [00007fadd47be490] chain filter error: Too high level of recursion (3)
# [00007fadd40203e0] main filter error: Failed to create video converter
# [00007fadd47be490] chain filter error: Too high level of recursion (3)
# [00007fadd40203e0] main filter error: Failed to create video converter
# [00007fadd47be490] chain filter error: Too high level of recursion (3)
# [00007fadd40203e0] main filter error: Failed to create video converter
# [00007fadd47be490] chain filter error: Too high level of recursion (3)
# [00007fadd40203e0] main filter error: Failed to create video converter
# [00007fadd4020840] main filter error: Failed to create video converter
# [00007fade0117710] main video output error: Failed to create video converter
# [00007fade0117710] main video output error: Failed to compensate for the format changes, removing all filters
# [00007fadd4020cb0] transform filter error: Unsupported pixel size 0 (chroma VAOP)
# [00007fadd4480d10] chain filter error: Too high level of recursion (3)
# [00007fadd47be490] main filter error: Failed to create video converter
# [00007fadd4480d10] chain filter error: Too high level of recursion (3)
# [00007fadd47be490] main filter error: Failed to create video converter
# [00007fadd4480d10] chain filter error: Too high level of recursion (3)
# [00007fadd47be490] main filter error: Failed to create video converter
# [00007fadd4480d10] chain filter error: Too high level of recursion (3)
# [00007fadd47be490] main filter error: Failed to create video converter
# [00007fadd4480d10] chain filter error: Too high level of recursion (3)
# [00007fadd47be490] main filter error: Failed to create video converter
# [00007fadd4480d10] chain filter error: Too high level of recursion (3)
# [00007fadd47be490] main filter error: Failed to create video converter
# [00007fadd4480d10] chain filter error: Too high level of recursion (3)
# [00007fadd47be490] main filter error: Failed to create video converter
# [00007fadd40203e0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd47d0af0] chain filter error: Too high level of recursion (3)
# [00007fadd401ffc0] main filter error: Failed to create video converter
# [00007fadd40203e0] main filter error: Failed to create video converter
# [00007fade0117710] main video output error: Failed to create video converter
# [00007fade0117710] main video output error: Failed to compensate for the format changes, removing all filters
# [00007fadd4021120] transform filter error: Unsupported pixel size 0 (chroma VDV0)
# [00007fadd41d3d20] chain filter error: Too high level of recursion (3)
# [00007fadd4480d10] main filter error: Failed to create video converter
# [00007fadd41d3d20] chain filter error: Too high level of recursion (3)
# [00007fadd4480d10] main filter error: Failed to create video converter
# [00007fadd41d3d20] chain filter error: Too high level of recursion (3)
# [00007fadd4480d10] main filter error: Failed to create video converter
# [00007fadd41d3d20] chain filter error: Too high level of recursion (3)
# [00007fadd4480d10] main filter error: Failed to create video converter
# [00007fadd41d3d20] chain filter error: Too high level of recursion (3)
# [00007fadd4480d10] main filter error: Failed to create video converter
# [00007fadd41d3d20] chain filter error: Too high level of recursion (3)
# [00007fadd4480d10] main filter error: Failed to create video converter
# [00007fadd41d3d20] chain filter error: Too high level of recursion (3)
# [00007fadd4480d10] main filter error: Failed to create video converter
# [00007fadd47be490] main filter error: Failed to create video converter
# [00007fae20c14ef0] avcodec decoder: Using NVIDIA VDPAU Driver Shared Library  430.50  Thu Sep  5 22:38:52 CDT 2019 for hardware decoding
# [00007fadd41bfd70] chain filter error: Too high level of recursion (3)
# [00007fadd47d0af0] main filter error: Failed to create video converter
# [00007fadd41bfd70] chain filter error: Too high level of recursion (3)
# [00007fadd47d0af0] main filter error: Failed to create video converter
# [00007fadd41bfd70] chain filter error: Too high level of recursion (3)
# [00007fadd47d0af0] main filter error: Failed to create video converter
# [00007fadd41bfd70] chain filter error: Too high level of recursion (3)
# [00007fadd47d0af0] main filter error: Failed to create video converter
# [00007fadd41bfd70] chain filter error: Too high level of recursion (3)
# [00007fadd47d0af0] main filter error: Failed to create video converter
# [00007fadd41bfd70] chain filter error: Too high level of recursion (3)
# [00007fadd47d0af0] main filter error: Failed to create video converter
# [00007fadd41bfd70] chain filter error: Too high level of recursion (3)
# [00007fadd47d0af0] main filter error: Failed to create video converter
# [00007fadd47be490] main filter error: Failed to create video converter
# [00007fade0117710] main video output error: Failed to create video converter
# [00007fade0117710] main video output error: Failed to compensate for the format changes, removing all filters
# QObject::~QObject: Timers cannot be stopped from another thread
